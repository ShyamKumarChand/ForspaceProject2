# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame({'employee':['Raju','Rani','Ramesh','Ram'],
                   'group':['Accounting','Engineering','Engineering','HR']})

# %%
df2 = pd.DataFrame({'employee':['Raju','Rani','Ramesh','Ram'],
                   'hire_date':[2004,2008,2012,2014]})

# %%
pd.merge(df1,df2)
# Out:
#   employee        group  hire_date
# 0     Raju   Accounting       2004
# 1     Rani  Engineering       2008
# 2   Ramesh  Engineering       2012
# 3      Ram           HR       2014

# %%
df3 = pd.merge(df1,df2)

# %%
df3
# Out:
#   employee        group  hire_date
# 0     Raju   Accounting       2004
# 1     Rani  Engineering       2008
# 2   Ramesh  Engineering       2012
# 3      Ram           HR       2014

# %%
df4 = pd.DataFrame({'group':['Accounting','Engineering','HR'],
                   'Superviser':['Carly','guido','Smith']})

# %%
df4
# Out:
#          group Superviser
# 0   Accounting      Carly
# 1  Engineering      guido
# 2           HR      Smith

# %%
df5 = pd.DataFrame({'group':['Accounting','Accounting',
                                         'Engineering','Engineering','HR','hdf4'],
                    'skill':['Math','spreadsheet','codeing','linux','spreadsheet','organisation']})

# %%
df5
# Out:
#          group         skill
# 0   Accounting          Math
# 1   Accounting   spreadsheet
# 2  Engineering       codeing
# 3  Engineering         linux
# 4           HR   spreadsheet
# 5         hdf4  organisation

# %%
df6 = pd.merge(df4,df5)

# %%
df6
# Out:
#          group Superviser        skill
# 0   Accounting      Carly         Math
# 1   Accounting      Carly  spreadsheet
# 2  Engineering      guido      codeing
# 3  Engineering      guido        linux
# 4           HR      Smith  spreadsheet

# %%
pd.merge(df1,df2, on='employee')
# Out:
#   employee        group  hire_date
# 0     Raju   Accounting       2004
# 1     Rani  Engineering       2008
# 2   Ramesh  Engineering       2012
# 3      Ram           HR       2014

# %%
df3  = pd.DataFrame({'name':['Raju','Ramesh','Rani','Ram'],
                    'salary':[7000,8000,12000,9000]})

# %%
df3
# Out:
#      name  salary
# 0    Raju    7000
# 1  Ramesh    8000
# 2    Rani   12000
# 3     Ram    9000

# %%
pd.merge(df1,df3,left_on='employee',right_on='name').drop('name',axis=1)
# Out:
#   employee        group  salary
# 0     Raju   Accounting    7000
# 1     Rani  Engineering   12000
# 2   Ramesh  Engineering    8000
# 3      Ram           HR    9000

# %%
df1a = df1.set_index('employee')
df2a = df2.set_index('employee')
df1a
# Out:
#                 group
# employee
# Raju       Accounting
# Rani      Engineering
# Ramesh    Engineering
# Ram                HR

# %%
df2a
# Out:
#           hire_date
# employee
# Raju           2004
# Rani           2008
# Ramesh         2012
# Ram            2014

# %%
pd.merge(df1a,df3, left_index=True,right_on='name')
# Out:
#          group    name  salary
# 0   Accounting    Raju    7000
# 2  Engineering    Rani   12000
# 1  Engineering  Ramesh    8000
# 3           HR     Ram    9000

# %%
pd.merge(df1a,df2a, left_index=True,right_index=True)
# Out:
#                 group  hire_date
# employee
# Raju       Accounting       2004
# Rani      Engineering       2008
# Ramesh    Engineering       2012
# Ram                HR       2014

# %%
df1a.join(df2a)
# Out:
#                 group  hire_date
# employee
# Raju       Accounting       2004
# Rani      Engineering       2008
# Ramesh    Engineering       2012
# Ram                HR       2014

# %%
pd.merge(df1a,df3, left_index=True,right_on='name')
# Out:
#          group    name  salary
# 0   Accounting    Raju    7000
# 2  Engineering    Rani   12000
# 1  Engineering  Ramesh    8000
# 3           HR     Ram    9000

# %%
df6 = pd.DataFrame({'name':['Peter','Paul','Marry'],
                   'food':['fish','beans','bread']},
                   columns=['name','food'])
df6
# Out:
#     name   food
# 0  Peter   fish
# 1   Paul  beans
# 2  Marry  bread

# %%
df7 = pd.DataFrame({'name':['Peter','Paul','Marry'],
                   'drink':['wine','bear','water']},
                   columns=['name','drink'])
df7
# Out:
#     name  drink
# 0  Peter   wine
# 1   Paul   bear
# 2  Marry  water

# %%
pd.merge(df6,df7)
# Out:
#     name   food  drink
# 0  Peter   fish   wine
# 1   Paul  beans   bear
# 2  Marry  bread  water

# %%
pd.merge(df6,df7, how='inner')
# Out:
#     name   food  drink
# 0  Peter   fish   wine
# 1   Paul  beans   bear
# 2  Marry  bread  water

# %%
pd.merge(df6,df7, how='outer')
# Out:
#     name   food  drink
# 0  Peter   fish   wine
# 1   Paul  beans   bear
# 2  Marry  bread  water

# %%
pd.merge(df6,df7, how='left')
# Out:
#     name   food  drink
# 0  Peter   fish   wine
# 1   Paul  beans   bear
# 2  Marry  bread  water

# %%
pd.merge(df6,df7, how='right')
# Out:
#     name   food  drink
# 0  Peter   fish   wine
# 1   Paul  beans   bear
# 2  Marry  bread  water

# %%
df8 = pd.DataFrame({'name':['Bob','Jack','Lisa','Sue'],
                   'rank':[1,2,3,4]})
df8
# Out:
#    name  rank
# 0   Bob     1
# 1  Jack     2
# 2  Lisa     3
# 3   Sue     4

# %%
df9 = pd.DataFrame({'name':['Bob','Jack','Lisa','Sue'],
                   'rank':[3,1,4,2]})
df9
# Out:
#    name  rank
# 0   Bob     3
# 1  Jack     1
# 2  Lisa     4
# 3   Sue     2

# %%
pd.merge(df8,df9,on='name')
# Out:
#    name  rank_x  rank_y
# 0   Bob       1       3
# 1  Jack       2       1
# 2  Lisa       3       4
# 3   Sue       4       2

# %%
abbrevs = pd.read_csv('https://raw.githubusercontent.com/reddyprasade/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/state-abbrevs.csv')
areas = pd.read_csv('https://raw.githubusercontent.com/reddyprasade/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/state-areas.csv')
Pop = pd.read_csv('https://raw.githubusercontent.com/reddyprasade/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/state-population.csv')

# %%
abbrevs.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
areas = pd.read_csv('https://raw.githubusercontent.com/reddyprasade/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/state-areas.csv')

# %%
areas.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
Pop = pd.read_csv('https://raw.githubusercontent.com/reddyprasade/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/state-population.csv')

# %%
Pop.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %%
abbrevs.shape
# Out:
# (51, 2)

# %%
areas.shape
# Out:
# (52, 2)

# %%
Pop.shape
# Out:
# (2544, 4)

# %%
abbrevs.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
areas.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
Pop.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %%
abbrevs.shape,areas.shape,Pop.shape
# Out:
# ((51, 2), (52, 2), (2544, 4))

# %%
abbrevs.head(),areas.head(),Pop.head()
# Out:
# (        state abbreviation
#  0     Alabama           AL
#  1      Alaska           AK
#  2     Arizona           AZ
#  3    Arkansas           AR
#  4  California           CA,
#          state  area (sq. mi)
#  0     Alabama          52423
#  1      Alaska         656425
#  2     Arizona         114006
#  3    Arkansas          53182
#  4  California         163707,
#    state/region     ages  year  population
#  0           AL  under18  2012   1117489.0
#  1           AL    total  2012   4817528.0
#  2           AL  under18  2010   1130966.0
#  3           AL    total  2010   4785570.0
#  4           AL  under18  2011   1125763.0)

# %%
Pop.isna().sum()
# Out:
# state/region     0
# ages             0
# year             0
# population      20
# dtype: int64

# %%
areas.isna().sum()
# Out:
# state            0
# area (sq. mi)    0
# dtype: int64

# %%
abbrevs.isna().sum()
# Out:
# state           0
# abbreviation    0
# dtype: int64

# %%
Merged = pd.merge(Pop,abbrevs,how='outer',
                 left_on='state/region',right_on='abbreviation')
Merged.head()
# Out:
#   state/region     ages  year  population    state abbreviation
# 0           AL  under18  2012   1117489.0  Alabama           AL
# 1           AL    total  2012   4817528.0  Alabama           AL
# 2           AL  under18  2010   1130966.0  Alabama           AL
# 3           AL    total  2010   4785570.0  Alabama           AL
# 4           AL  under18  2011   1125763.0  Alabama           AL

# %%
Merged.isna().sum()
# Out:
# state/region     0
# ages             0
# year             0
# population      20
# state           96
# abbreviation    96
# dtype: int64

# %%
Merged.loc[Merged['state/region'] == 'PR','state'] = 'Puerto Rico'

# %%
Merged.loc[Merged['state/region'] == 'USA','state'] = 'United States'

# %%
Merged.isnull().sum()
# Out:
# state/region     0
# ages             0
# year             0
# population      20
# state            0
# abbreviation    96
# dtype: int64

# %%
final = pd.merge(Merged, areas, on='state', how='left')
final.head()
# Out:
#   state/region     ages  year  population    state abbreviation  area (sq. mi)
# 0           AL  under18  2012   1117489.0  Alabama           AL        52423.0
# 1           AL    total  2012   4817528.0  Alabama           AL        52423.0
# 2           AL  under18  2010   1130966.0  Alabama           AL        52423.0
# 3           AL    total  2010   4785570.0  Alabama           AL        52423.0
# 4           AL  under18  2011   1125763.0  Alabama           AL        52423.0

# %%
final.isnull().any()
# Out:
# state/region     False
# ages             False
# year             False
# population        True
# state            False
# abbreviation      True
# area (sq. mi)     True
# dtype: bool

# %%
final['state'][final['area (sq. mi)'].isnull()].unique()
# Out:
# array(['United States'], dtype=object)

# %%
final.isnull().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2544 entries, 0 to 2543
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state/region   2544 non-null   bool
#  1   ages           2544 non-null   bool
#  2   year           2544 non-null   bool
#  3   population     2544 non-null   bool
#  4   state          2544 non-null   bool
#  5   abbreviation   2544 non-null   bool
#  6   area (sq. mi)  2544 non-null   bool
# dtypes: bool(7)
# memory usage: 37.3 KB

# %%
final.isna().sum()
# Out:
# state/region      0
# ages              0
# year              0
# population       20
# state             0
# abbreviation     96
# area (sq. mi)    48
# dtype: int64

# %%
data2010 = final.query("year == 2010 & ages == 'total'") # SQL Select Stastement
data2010.head()
# Out:
#     state/region   ages  year  population       state abbreviation  \
# 3             AL  total  2010   4785570.0     Alabama           AL
# 91            AK  total  2010    713868.0      Alaska           AK
# 101           AZ  total  2010   6408790.0     Arizona           AZ
# 189           AR  total  2010   2922280.0    Arkansas           AR
# 197           CA  total  2010  37333601.0  California           CA
#
#      area (sq. mi)
# 3          52423.0
# 91        656425.0
# 101       114006.0
# 189        53182.0
# 197       163707.0

# %%
data2010.set_index('state', inplace=True)
data2010
# Out:
#                      state/region   ages  year   population abbreviation  \
# state
# Alabama                        AL  total  2010    4785570.0           AL
# Alaska                         AK  total  2010     713868.0           AK
# Arizona                        AZ  total  2010    6408790.0           AZ
# Arkansas                       AR  total  2010    2922280.0           AR
# California                     CA  total  2010   37333601.0           CA
# Colorado                       CO  total  2010    5048196.0           CO
# Connecticut                    CT  total  2010    3579210.0           CT
# Delaware                       DE  total  2010     899711.0           DE
# District of Columbia           DC  total  2010     605125.0           DC
# Florida                        FL  total  2010   18846054.0           FL
# Georgia                        GA  total  2010    9713248.0           GA
# Hawaii                         HI  total  2010    1363731.0           HI
# ...

# %%
density = data2010['population'] / data2010['area (sq. mi)']
density.head()
# Out:
# state
# Alabama        91.287603
# Alaska          1.087509
# Arizona        56.214497
# Arkansas       54.948667
# California    228.051342
# dtype: float64

# %%
density.sort_values(ascending=True, inplace=True)
density.head()
# Out:
# state
# Alaska           1.087509
# Wyoming          5.768079
# Montana          6.736171
# North Dakota     9.537565
# South Dakota    10.583512
# dtype: float64

# %%
Data = pd.to_pickle(final,'US_States_Data.plk')# Save the Data

# %%
Data

# %%
final.to_csv('US_States_Data.csv')# Save the Data Csv

# %%
unpickled_df = pd.read_pickle("US_States_Data.plk")
unpickled_df
# Out:
#      state/region     ages  year   population          state abbreviation  \
# 0              AL  under18  2012    1117489.0        Alabama           AL
# 1              AL    total  2012    4817528.0        Alabama           AL
# 2              AL  under18  2010    1130966.0        Alabama           AL
# 3              AL    total  2010    4785570.0        Alabama           AL
# 4              AL  under18  2011    1125763.0        Alabama           AL
# ...           ...      ...   ...          ...            ...          ...
# 2539          USA    total  2010  309326295.0  United States          NaN
# 2540          USA  under18  2011   73902222.0  United States          NaN
# 2541          USA    total  2011  311582564.0  United States          NaN
# 2542          USA  under18  2012   73708179.0  United States          NaN
# 2543          USA    total  2012  313873685.0  United States          NaN
#
#       area (sq. mi)
# 0           52423.0
# 1           52423.0
# ...
